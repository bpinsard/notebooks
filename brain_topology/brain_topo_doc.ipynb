# %%
# %pylab inline
import sys
project_folder = '/media/77f462a2-7290-437d-8209-c1e673ed635a/projects/brain_topology'
sys.path.insert(0,project_folder+'/code/')
from dionysus import PairwiseDistances
from mayavi import mlab
import scipy
import scipy.sparse.linalg
import topology
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['mlab']
# `%matplotlib` prevents importing * from pylab and numpy

# %% [markdown]
# ## loading data
# loading some anatomical connectivity data, normalizing by the size of the ROIs
#
# There are 800 cortical ROIs that are selected (the 19 first ROIs are subcortical), and we normalize by the maximum connectivity "density".
#
# The CorrelationDistance object is just a proxy because the software is working usually from coordinates, this class just enables to give either correlation matrix or any matrix bounded by 1 and return 1-<this value> as the distance used for filtration in persistent homology.
#
# for persistent homology the order in more important than the value, monotonic changes to the distance value will only stretch the barcode

# %%
cens=np.load(project_folder+'/tmp_data/rois_cens_wld_800.npy')
conn819=np.loadtxt(project_folder+'/tmp_data/connect_800.csv')
conn819_2=(conn819+conn819.T)/(1+np.eye(819))
voxcount=np.load(project_folder+'/tmp_data/labels_voxcount800.npy')
voxprob=voxcount/float(voxcount.sum())
voxpairprob=voxprob[:,np.newaxis]*voxprob[np.newaxis]
nconn819=conn819_2/conn819_2.sum()/voxpairprob
dists=topology.CorrelationDistance(nconn819[19:,19:]/nconn819[19:,19:].max())

# %% [markdown]
# ## simplicial complex and filtration
# This creates the sorted simplicial complex (or filtration).
# It can take a few minutes if the number of points is important or the maximum value of the filtration is high.
#
# - The first argument is the distance object
# - The second is the maximum size of simplices we want to create in that case 3=tetrahedron, it is necessary to compute tetrahedron to find 2-cycles (voids), because tetrahedron will "kill the voids and enable to find the end of the cycle. In the case we only want [0-1]-cycles, 2 is enough.
# - The last argument is the maximum filtration value so it defines the extent of the barcode we are going to compute.
#
# The output is a list of simplices ordered by increasing filtration value (which is necessary to compute (co)-homology)

# %%
order=3
max_filt_value=.97
filt=topology.create_filtration(dists,order,max_filt_value)
# Out:
# 39206 simplices

# %% [markdown]
# ## computing persistent homology
# This function computes homology of the simplicial complex filtration, up to the order (sometimes also called skeleton size) specified, in that case 3.
#
# (Computation can be long if the filtration is huge, I added a progress display.).
#
# cyc is a list of tuples describing the cycles as :
#
# - the order of the cycle (0=clusters,1=cycle,2=voids,...)
# - the birth value = the filtration value at which the cycle appear
# - the death value = the filtration value at which the cycle is killed, infinite if still alive
# - the simplex that killed the cycle if dead
# - the simplices of a representative of the cycle

# %%
cyc=topology.homology_cycles(filt,order)
# Out:
# processing....
# 0.00% done
# 1.00% done
# 2.00% done
# 3.00% done
# 4.00% done
# 5.00% done
# 6.00% done
# 7.00% done
# 8.00% done
# 9.00% done
# 10.00% done
# 11.00% done
# 12.00% done
# 13.00% done
# 14.00% done
# 15.00% done
# 16.00% done
# 17.00% done
# 18.00% done
# 19.00% done
# 20.00% done
# 21.00% done
# 22.00% done
# 23.00% done
# 24.00% done
# 25.00% done
# 26.00% done
# 27.00% done
# 28.00% done
# 29.00% done
# 30.00% done
# 31.00% done
# 32.00% done
# 33.00% done
# 34.00% done
# 35.00% done
# 36.00% done
# 37.00% done
# 38.00% done
# 39.00% done
# 40.00% done
# 41.00% done
# 42.00% done
# 43.00% done
# 44.00% done
# 45.00% done
# 46.00% done
# 47.00% done
# 48.00% done
# 49.00% done
# 50.00% done
# 51.00% done
# 52.00% done
# 53.00% done
# 54.00% done
# 55.00% done
# 56.00% done
# 57.00% done
# 58.00% done
# 59.00% done
# 60.00% done
# 61.00% done
# 62.00% done
# 63.00% done
# 64.00% done
# 65.00% done
# 66.00% done
# 67.00% done
# 68.00% done
# 69.00% done
# 70.00% done
# 71.00% done
# 72.00% done
# 73.00% done
# 74.00% done
# 75.00% done
# 76.00% done
# 77.00% done
# 78.00% done
# 79.00% done
# 80.00% done
# 81.00% done
# 82.00% done
# 83.00% done
# 84.00% done
# 85.00% done
# 86.00% done
# 87.00% done
# 88.00% done
# 89.00% done
# 90.00% done
# 91.00% done
# 92.00% done
# 93.00% done
# 94.00% done
# 95.00% done
# 96.00% done
# 97.00% done
# 98.00% done
# 99.00% done
# 100.00% done

# %% [markdown]
# ## computing persistent homology
# This function computes cohomology of the simplicial complex filtration, similarly to the homology.
#
# outputs is a list of tuples with:
#
# - cocycle order
# - birth filtration value
# - death filtration value, inf is still alive
# - the simplex that killed the cycle if dead
# - the zcolumn if dead or the cocycle object
# - the simplices of a representative of the cocycle

# %%
ccyc,ch=topology.cohomology_cycles(filt,3)
# Out:
# processing....
# 0.00% done
# 1.00% done
# 2.00% done
# 3.00% done
# 4.00% done
# 5.00% done
# 6.00% done
# 7.00% done
# 8.00% done
# 9.00% done
# 10.00% done
# 11.00% done
# 12.00% done
# 13.00% done
# 14.00% done
# 15.00% done
# 16.00% done
# 17.00% done
# 18.00% done
# 19.00% done
# 20.00% done
# 21.00% done
# 22.00% done
# 23.00% done
# 24.00% done
# 25.00% done
# 26.00% done
# 27.00% done
# 28.00% done
# 29.00% done
# 30.00% done
# 31.00% done
# 32.00% done
# 33.00% done
# 34.00% done
# 35.00% done
# 36.00% done
# 37.00% done
# 38.00% done
# 39.00% done
# 40.00% done
# 41.00% done
# 42.00% done
# 43.00% done
# 44.00% done
# 45.00% done
# 46.00% done
# 47.00% done
# 48.00% done
# 49.00% done
# 50.00% done
# 51.00% done
# 52.00% done
# 53.00% done
# 54.00% done
# 55.00% done
# 56.00% done
# 57.00% done
# 58.00% done
# 59.00% done
# 60.00% done
# 61.00% done
# 62.00% done
# 63.00% done
# 64.00% done
# 65.00% done
# 66.00% done
# 67.00% done
# 68.00% done
# 69.00% done
# 70.00% done
# 71.00% done
# 72.00% done
# 73.00% done
# 74.00% done
# 75.00% done
# 76.00% done
# 77.00% done
# 78.00% done
# 79.00% done
# 80.00% done
# 81.00% done
# 82.00% done
# 83.00% done
# 84.00% done
# 85.00% done
# 86.00% done
# 87.00% done
# 88.00% done
# 89.00% done
# 90.00% done
# 91.00% done
# 92.00% done
# 93.00% done
# 94.00% done
# 95.00% done
# 96.00% done
# 97.00% done
# 98.00% done
# 99.00% done
# 100.00% done

# %% [markdown]
# ## fancy barcode representation
# Plotting the barcode, horizontal axis indexes the filtration value and each bar is a cycle, each section is for the different orders of cycles, 0,1,2
#
# Each bar in a cycle and it's start and end are set as the filtration value at which they appear and disappear respectively.
#
# This could be done either using the results of homology or cohomology as cycles and cocycles are duals.
#
# due to oddly distributed distances, the topological features only appear at the end of the filtration
#
#
# The 3 parts are:
#
# - 0-cycles which corresponds to clusters of the graph
# - 1-cycles which are "holes" in the topology
# - 1-cycles as voids in the topology

# %%
barcode=topology.plot_barcode(cyc,order,max_filt_value)

# %% [markdown]
# ## boundary matrix representation / operators
# We here compute the boundary matrices as sparse matrices, which are the incidence matrices for simplices of increasing order
# $$\delta_0,...\delta_n$$
# the dual of the boundary operator are the transpose
# $$\delta^*_0,...\delta^*_n$$
# all the matrices are relating $n$ with $n+1$ simplices
# thus will be of size $|vertices|\times|edges|, |edges|\times|triangles|$...

# %%
mxs=topology.boundary_mx(filt,3)
mxs
# Out:
# [<800x5620 sparse matrix of type '<type 'numpy.float64'>'
#  	with 11240 stored elements in COOrdinate format>,
#  <5620x13786 sparse matrix of type '<type 'numpy.float64'>'
#  	with 41358 stored elements in COOrdinate format>,
#  <13786x19000 sparse matrix of type '<type 'numpy.float64'>'
#  	with 76000 stored elements in COOrdinate format>]

# %% [markdown]
# # Laplacians
# computing the laplacian of order 0, still using sparse matrices, this is easy: $ \mathcal{L}_0 = \delta_0 \delta^*_0$

# %%
l0 = mxs[0].dot(mxs[0].T)
l0
# Out:
# <800x800 sparse matrix of type '<type 'numpy.float64'>'
# 	with 12040 stored elements in Compressed Sparse Row format>

# %% [markdown]
# ## Decomposition of the laplacian
# we compute the svd of the laplacian, we first convert the laplacian to dense matrix as it is small enough and thus faster to decompose using standard algorithm, and a quick display of the eigenvalues and eigenvectors matrix.
#
# In that case there is only one zero eigenvalue as there is only one connected component in the simplicial complex.

# %%
el0=np.linalg.eigh(np.asarray(l0.todense()))

# %%
plot(el0[0])
matshow(el0[1],vmin=-.1,vmax=.1)

# %%
from IPython.display import Image

# %% [markdown]
# # A few eigenvectors corresponding to smallest non-zeros eigenvalues
# The graph is fully connected, so the first eigenvector is constant.
#
# The smallest non-zeros eigenvalues correspond to parameterization of the graph.
#
# The largest eigenvalues correspond to local clusters as visible in the matrix above.
#
# In between a bunch of clusters/networks.

# %%
Image(filename='/home/bpinsard/data/projects/brain_topology/results/cycle0_1.png')

# %%
Image(filename='/home/bpinsard/data/projects/brain_topology/results/cycle0_2.png')

# %%
Image(filename='/home/bpinsard/data/projects/brain_topology/results/cycle0_3.png')

# %% [markdown]
# ## higher-order laplacian
# then compute the laplacian at order 1, which is the sum of laplacians "up" and "down"
#
# $$ \mathcal{L}_k = \delta_{k+1} \delta^*_{k+1} + \delta^*_{k} \delta_{k}$$

# %%
l1 = mxs[1].dot(mxs[1].T) + mxs[0].T.dot(mxs[0])
l1.shape
# Out:
# (5620, 5620)

# %% [markdown]
# ###Normalized laplacian
# $ \mathscr{L}_k = D_k^{-1/2}\mathcal{L}_k D_k^{-1/2} $
#
# $ D_k = diag(\mathcal{L}_k) $

# %%
l1n = topology.lap_norm(l1)
l1n
# Out:
# <5620x5620 sparse matrix of type '<type 'numpy.float64'>'
# 	with 121754 stored elements in Compressed Sparse Row format>

# %% [markdown]
# ###decomposition
# this is a quite big matrix to decompose, we are here forced to use some sparse algorithm and choose a subset of eigenvectors/values to get, either from the top or bottom of the spectrum, we here do both for 100 evs.
# this can take quite a long time to compute for the small eigenvalues due to slow convergence, please be patient.
#
# we here decompose the 100 smallest eigenvectors both unnormalized and normalized laplacian

# %%
el1_bot=scipy.sparse.linalg.eigsh(l1,k=100,which='SM')
el1n_bot=scipy.sparse.linalg.eigsh(l1n.astype(np.float),k=100,which='SM')

# %% [markdown]
# ### plot the eigenspectrum in logscale (for easier comparison of unnormalized and normalized)

# %%
semilogy(el1_bot[0]);semilogy(el1n_bot[0]);

# %% [markdown]
# ### show the eigenvectors for unnormalized and normalized

# %%
matshow(el1_bot[1].T,aspect='auto',vmin=-.1,vmax=.1,label='')
matshow(el1n_bot[1].T,aspect='auto',vmin=-.1,vmax=.1)

# %% [markdown]
# now we can display the results on the brain coordinates in 3d,

# %% [markdown]
# ## An almost-zero eigenvalue eigenvector
# The eigenvector is thresholded to remove the close to zero connections.
#
# The highest and lowest weights on the eigenvectors correspond to some sort of bottleneck (as would be detected in max-flow min-cut) in the cycle structure, so you have to imagine the ring as a sort of ribbon loop where the ribbon does not have constant width.
#
# A nice ring-like structure.

# %%
Image(filename='/home/bpinsard/data/projects/brain_topology/results/cycle_ring.png')

# %% [markdown]
# # Another one

# %%
Image(filename='/home/bpinsard/data/projects/brain_topology/results/cycle1.png')
